# %% [markdown]
# # **Big Basket 🧺**
#   # **Forget the days of grocery shopping being a chore! Imagine this: you're lounging on the couch, phone in hand, and with a few taps you've got a truckload (well, maybe a basketful) of fresh produce, pantry staples, and even household essentials on their way to your doorstep. That's the magic of bigbasket, India's one stop grocery shopping destination.**
#
#   # **They've got over 20,000 products from all your favorite brands, so you can stock up on everything you need without ever leaving home. Fruits and veggies? Got it. Dairy and meat for that epic dinner party? No problem. Bigbasket even has beauty supplies and cleaning products, so you can basically tackle your entire shopping list in one place. Plus, they have crazy convenient delivery options, so you can ditch the supermarket lines and spend that time doing way cooler things (like prepping for that dinner party!). Bigbasket basically makes grocery shopping a breeze, so you can get back to the fun stuff.**

# %% [markdown]
# <hr>
#
# # **About the dataset 📊**
#
# **This dataset is basically a big ol' bunch of info about products, all broken down into 10 easy-peasy pieces:**
#
#   * **Index: This is just a fancy way of saying it's a unique ID for each item, like a fingerprint in the data world.**
#   * **Product: The name of the product, just like you'd see it on the website.**
#   * **Category: The broad group the product falls into, like groceries or home stuff.**
#   * **Sub-Category: This is like zooming in on the category. So, maybe "groceries" becomes "fruits" or "home stuff" becomes "cleaning supplies."**
#   * **Brand: Who makes the product? You know, like Nike or that yummy jam brand you love.**
#   * **Sale Price: How much you gotta pay for it right now.**
#   * **Market Price: This is kind of like a reference point, showing the usual price for the product.**
#   * **Type: Another way to classify the product, just for extra organization.**
#   * **Rating: What other customers think! This is a number showing how much people liked it.**
#   * **Description: This is where they tell you all the juicy details about the dataset itself, what it includes and how it's put together**

# %% [markdown]
# <hr>
#
# **Link to the dataset: https://drive.google.com/file/d/1aEuXxadTlHS4d_BBqrhVVurOFI154ATS/view?usp=sharing**

# %% [markdown]
# <hr>
#
# # **Step 1 - Importing the libraries 📚**

# %% [markdown]
# **Configuration Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Mandatory Libraries**

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# **External Libraries**

# %%
# !pip install colorama
import colorama
from colorama import Fore, Back, Style
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# <hr>
#
# # **Step 2 - Data Loading and Inspection 🌐**

# %% [markdown]
# **Data Loading**

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/BBData.csv")

# %% [markdown]
# **Data Inspection**

# %%
df.head().style.set_properties(
    **{
        "background-color":"wh",
        "border-style":"solid",
        "border-color":"white",
    }
)
# Out:
# <style type="text/css">
# #T_07219_row0_col0, #T_07219_row0_col1, #T_07219_row0_col2, #T_07219_row0_col3, #T_07219_row0_col4, #T_07219_row0_col5, #T_07219_row0_col6, #T_07219_row0_col7, #T_07219_row0_col8, #T_07219_row0_col9, #T_07219_row0_col10, #T_07219_row1_col0, #T_07219_row1_col1, #T_07219_row1_col2, #T_07219_row1_col3, #T_07219_row1_col4, #T_07219_row1_col5, #T_07219_row1_col6, #T_07219_row1_col7, #T_07219_row1_col8, #T_07219_row1_col9, #T_07219_row1_col10, #T_07219_row2_col0, #T_07219_row2_col1, #T_07219_row2_col2, #T_07219_row2_col3, #T_07219_row2_col4, #T_07219_row2_col5, #T_07219_row2_col6, #T_07219_row2_col7, #T_07219_row2_col8, #T_07219_row2_col9, #T_07219_row2_col10, #T_07219_row3_col0, #T_07219_row3_col1, #T_07219_row3_col2, #T_07219_row3_col3, #T_07219_row3_col4, #T_07219_row3_col5, #T_07219_row3_col6, #T_07219_row3_col7, #T_07219_row3_col8, #T_07219_row3_col9, #T_07219_row3_col10, #T_07219_row4_col0, #T_07219_row4_col1, #T_07219_row4_col2, #T_07219_row4_col3, #T_07219_row4_col4, #T_07219_row4_col5, #T_07219_row4_col6, #T_07219_row4_col7, #T_07219_row4_col8, #T_07219_row4_col9, #T_07219_row4_col10 {
#   background-color: wh;
#   border-style: solid;
#   border-color: white;
# }
# </style>
# <table id="T_07219" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07219_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_07219_level0_col1" class="col_heading level0 col1" >product</th>
#       <th id="T_07219_level0_col2" class="col_heading level0 col2" >category</th>
#       <th id="T_07219_level0_col3" class="col_heading level0 col3" >sub_category</th>
#       <th id="T_07219_level0_col4" class="col_heading level0 col4" >brand</th>
#       <th id="T_07219_level0_col5" class="col_heading level0 col5" >sale_price</th>
#       <th id="T_07219_level0_col6" class="col_heading level0 col6" >market_price</th>
#       <th id="T_07219_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_07219_level0_col8" class="col_heading level0 col8" >rating</th>
#       <th id="T_07219_level0_col9" class="col_heading level0 col9" >description</th>
#       <th id="T_07219_level0_col10" class="col_heading level0 col10" >discounts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07219_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07219_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_07219_row0_col1" class="data row0 col1" >Garlic Oil - Vegetarian Capsule 500 mg</td>
#       <td id="T_07219_row0_col2" class="data row0 col2" >Beauty & Hygiene</td>
#       <td id="T_07219_row0_col3" class="data row0 col3" >Hair Care</td>
#       <td id="T_07219_row0_col4" class="data row0 col4" >Sri Sri Ayurveda </td>
#       <td id="T_07219_row0_col5" class="data row0 col5" >220</td>
#       <td id="T_07219_row0_col6" class="data row0 col6" >220</td>
#       <td id="T_07219_row0_col7" class="data row0 col7" >Hair Oil & Serum</td>
#       <td id="T_07219_row0_col8" class="data row0 col8" >4.100000</td>
#       <td id="T_07219_row0_col9" class="data row0 col9" >This Product contains Garlic Oil that is known to help proper digestion, maintain proper cholesterol levels, support cardiovascular and also build immunity.  For Beauty tips, tricks & more visit https://bigbasket.blog/</td>
#       <td id="T_07219_row0_col10" class="data row0 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_07219_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07219_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_07219_row1_col1" class="data row1 col1" >Water Bottle - Orange</td>
#       <td id="T_07219_row1_col2" class="data row1 col2" >Kitchen, Garden & Pets</td>
#       <td id="T_07219_row1_col3" class="data row1 col3" >Storage & Accessories</td>
#       <td id="T_07219_row1_col4" class="data row1 col4" >Mastercook</td>
#       <td id="T_07219_row1_col5" class="data row1 col5" >180</td>
#       <td id="T_07219_row1_col6" class="data row1 col6" >180</td>
#       <td id="T_07219_row1_col7" class="data row1 col7" >Water & Fridge Bottles</td>
#       <td id="T_07219_row1_col8" class="data row1 col8" >2.300000</td>
#       <td id="T_07219_row1_col9" class="data row1 col9" >Each product is microwave safe (without lid), refrigerator safe, dishwasher safe and can also be used for re-heating food and not for cooking. All containers come with airtight lids and a wide variety of attractive colours. Stack these stylish and colourful containers in your kitchen with ease and for a look-good factor.</td>
#       <td id="T_07219_row1_col10" class="data row1 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_07219_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07219_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_07219_row2_col1" class="data row2 col1" >Brass Angle Deep - Plain, No.2</td>
#       <td id="T_07219_row2_col2" class="data row2 col2" >Cleaning & Household</td>
#       <td id="T_07219_row2_col3" class="data row2 col3" >Pooja Needs</td>
#       <td id="T_07219_row2_col4" class="data row2 col4" >Trm</td>
#       <td id="T_07219_row2_col5" class="data row2 col5" >119</td>
#       <td id="T_07219_row2_col6" class="data row2 col6" >250</td>
#       <td id="T_07219_row2_col7" class="data row2 col7" >Lamp & Lamp Oil</td>
#       <td id="T_07219_row2_col8" class="data row2 col8" >3.400000</td>
#       <td id="T_07219_row2_col9" class="data row2 col9" >A perfect gift for all occasions, be it your mother, sister, in-laws, boss or your friends, this beautiful designer piece wherever placed, is sure to beautify the surroundings Traditional design This type diya has been used for Diwali and All other Festivals for centuries. Sturdy and easy to carry The feet keep it balanced to ensure safety. Wonderful Oil Lamp made in Brass also called as Jyoti. This is a handcrafted piece of Indian brass Deepak.</td>
#       <td id="T_07219_row2_col10" class="data row2 col10" >52.400000</td>
#     </tr>
#     <tr>
#       <th id="T_07219_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07219_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_07219_row3_col1" class="data row3 col1" >Cereal Flip Lid Container/Storage Jar - Assorted Colour</td>
#       <td id="T_07219_row3_col2" class="data row3 col2" >Cleaning & Household</td>
#       <td id="T_07219_row3_col3" class="data row3 col3" >Bins & Bathroom Ware</td>
#       <td id="T_07219_row3_col4" class="data row3 col4" >Nakoda</td>
#       <td id="T_07219_row3_col5" class="data row3 col5" >149</td>
#       <td id="T_07219_row3_col6" class="data row3 col6" >176</td>
#       <td id="T_07219_row3_col7" class="data row3 col7" >Laundry, Storage Baskets</td>
#       <td id="T_07219_row3_col8" class="data row3 col8" >3.700000</td>
#       <td id="T_07219_row3_col9" class="data row3 col9" >Multipurpose container with an attractive design and made from food-grade plastic for your hygiene and safety ideal for storing pulses. Grains, spices, and more with easy opening and closing flip-open lid. Strong, durable and transparent body for longevity and easy identification of contents. Multipurpose storage solution for your daily needs stores your everyday food essentials in style with the Nakoda container set. With transparent bodies, you can easily identify your stored items without having to open the lids. These containers are ideal for storing a large variety of items such as food grains, snacks and pulses to sugar, spices, condiments and more. Featuring unique flip-open lids, you can easily open and close this container without any hassles.
# The Nakoda container is made from high-quality food-grade and BPA-free plastic that is 100% safe for storing food items. You can safely store your food items in this container without worrying about contamination and harmful toxins. As they are constructed using highly durable virgin plastic, this container will last for a long time even with regular use. This container can enhance the overall look of your kitchen decor. Being dishwasher s

# %% [markdown]
# <hr>
#
# **Data Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# <hr>
#
# # **Step 3 - Data Cleaning and Processing**

# %% [markdown]
# **Shape Inspection**

# %%
a = df.shape
print(f"Rows: {a[0]} & Columns: {a[1]}")
# Out:
# Rows: 27555 & Columns: 10

# %% [markdown]
# **Null Check✅**

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
# Let's work with product columns
df["product"] = df["product"].fillna("NoProductName")
# If we are working with brand column
df["brand"] = df["brand"].fillna("UnknownBrand")

# Working with descriptions
df["description"] = df["description"].fillna("NoDescriptionAvailable")

# %% [markdown]
# <hr>
#
# **Rounding off the values**

# %%
# for sales price
df["sale_price"] = df["sale_price"].round().astype(int)

# For the market price
df["market_price"] = df["market_price"].round().astype(int)

# %% [markdown]
# <hr>
#
# # **Step 4 - Exploratory Data Analysis 📊**

# %% [markdown]
# <hr>
#
# **Objective 1: Find out the discounts based on the market price**

# %%
df["discounts"] = (((df["market_price"] - df["sale_price"]) / df["market_price"])*100)

# %%
df.head(2)
# Out:
#    index                                 product                category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1      2                   Water Bottle - Orange  Kitchen, Garden & Pets
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda          220           220
# 1  Storage & Accessories         Mastercook         180           180
#
#                      type  rating  \
# 0        Hair Oil & Serum     4.1
# 1  Water & Fridge Bottles     2.3
#
#                                          description  discounts
# 0  This Product contains Garlic Oil that is known...        0.0
# 1  Each product is microwave safe (without lid), ...        0.0

# %% [markdown]
# <hr>
#
# **Objective 2: Get a higher level overview of the data**

# %%
# Printing the same with the help of colorama
print(Back.BLACK + Style.BRIGHT + "Summary of the Inventory" + Style.RESET_ALL)

# Printing the total unique products available
print(Fore.RED + "Total Number of Unique Products Available: "+ Style.RESET_ALL + Fore.YELLOW + str(df["product"].nunique()) + Style.RESET_ALL)

# Printing the number of product categories available
print(Fore.BLUE + "Total Number of Unique Products Categories Available: "+ Style.RESET_ALL + Fore.YELLOW + str(df["category"].nunique()) + Style.RESET_ALL)

# Printing the total number of unique subcategories
print(Fore.GREEN + "Total Number of Unique Sub_Categories Available: "+ Style.RESET_ALL + Fore.YELLOW + str(df["sub_category"].nunique()) + Style.RESET_ALL)

# Printing the total types of products
print(Fore.CYAN + "Total Number of Unique Type Available: "+ Style.RESET_ALL + Fore.YELLOW + str(df["type"].nunique()) + Style.RESET_ALL)

# Printing all the brands that are available
print(Fore.RED + "Total Number of Unique Brand Available: "+ Style.RESET_ALL + Fore.YELLOW + str(df["brand"].nunique()) + Style.RESET_ALL)
# Out:
# Summary of the Inventory
# Total Number of Unique Products Available: 23541
# Total Number of Unique Products Categories Available: 11
# Total Number of Unique Sub_Categories Available: 90
# Total Number of Unique Type Available: 426
# Total Number of Unique Brand Available: 2314

# %% [markdown]
# **Insights**
#   * **The inventory as seen is good right now**

# %% [markdown]
# <hr>
#
# **Objective 3: Analysing the data on the basis on demands that is in Products & Categories**

# %%
# Grabbing the data from category and product
category_data = df[["category", "product"]]

# Since, we are counting the number of product, we are drop the duplicates
category_data = category_data.drop_duplicates()

# We are going to implement groupby
category_data = category_data.groupby("category").agg(product_count = ("product", "count")).reset_index().sort_values("product_count", ascending = False)

# %% [markdown]
# **Results**

# %%
category_data
# Out:
#                     category  product_count
# 2           Beauty & Hygiene           6839
# 8       Gourmet & World Food           4109
# 9     Kitchen, Garden & Pets           3186
# 10    Snacks & Branded Foods           2454
# 4       Cleaning & Household           2411
# 6   Foodgrains, Oil & Masala           1997
# 3                  Beverages            756
# 1      Bakery, Cakes & Dairy            752
# 0                  Baby Care            549
# 7        Fruits & Vegetables            353
# 5          Eggs, Meat & Fish            338

# %% [markdown]
# **Visualize**

# %%
fig = px.bar(category_data, x = "category", y = "product_count", color = "category", title = "Analysis on the product and category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="009b6f81-f7d8-417d-9c90-2884fefe0a5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("009b6f81-f7d8-417d-9c90-2884fefe0a5b")) {                    Plotly.newPlot(                        "009b6f81-f7d8-417d-9c90-2884fefe0a5b",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beauty & Hygiene","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Beauty & Hygiene","offsetgroup":"Beauty & Hygiene","orientation":"v","showlegend":true,"textposition":"auto","x":["Beauty & Hygiene"],"xaxis":"x","y":[6839],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gourmet & World Food","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Gourmet & World Food","offsetgroup":"Gourmet & World Food","orientation":"v","showlegend":true,"textposition":"auto","x":["Gourmet & World Food"],"xaxis":"x","y":[4109],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kitchen, Garden & Pets","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Kitchen, Garden & Pets","offsetgroup":"Kitchen, Garden & Pets","orientation":"v","showlegend":true,"textposition":"auto","x":["Kitchen, Garden & Pets"],"xaxis":"x","y":[3186],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Snacks & Branded Foods","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Snacks & Branded Foods","offsetgroup":"Snacks & Branded Foods","orientation":"v","showlegend":true,"textposition":"auto","x":["Snacks & Branded Foods"],"xaxis":"x","y":[2454],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cleaning & Household","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cleaning & Household","offsetgroup":"Cleaning & Household","orientation":"v","showlegend":true,"textposition":"auto","x":["Cleaning & Household"],"xaxis":"x","y":[2411],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foodgrains, Oil & Masala","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Foodgrains, Oil & Masala","offsetgroup":"Foodgrains, Oil & Masala","orientation":"v","showlegend":true,"textposition":"auto","x":["Foodgrains, Oil & Masala"],"xaxis":"x","y":[1997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Beverages","offsetgroup":"Beverages","orientation":"v","showlegend":true,"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[756],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bakery, Cakes & Dairy","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Bakery, Cakes & Dairy","offsetgroup":"Bakery, Cakes & Dairy","orientation":"v","showlegend":true,"textposition":"auto","x":["Bakery, Cakes & Dairy"],"xaxis":"x","y":[752],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eproduct_count=%{y}\u003ce ...

# %% [markdown]
# **Insights**
#   * **Out of all the given categories, `Beauty & Hygiene` is having the most products**
#   * **Followed by the same, the `Gourmet & World Food` and `Kitchen, Garden & Pets` are the ones that are in the top 3**
#   * **Given this data, we can easily analyse that demands are mostly from these three categories, since these categories combined have more products as compared to the rest of the data**
#   * **According to the given data, we can clearly see that there is a huge stock for Beauty and Hygiene**
#   * **Maybe, this is due to the upcoming trend of festival/ common reason**
#   * **So, going the recent reallife experience, we need to maximize the supply of beauty and hygiene category**

# %% [markdown]
# <hr>
#
# **Objective 4 - Analysis on the basis of Brand and Type, to know which are the brands that are famous among consumer and what kind of products are famous from those brands**

# %%
# Grabbing the data
brand_data = df[["brand", "type"]]

# Dropping the duplicates
brand_data = brand_data.drop_duplicates()

# We need to group the data
brand_data = brand_data.groupby("brand").agg(type_count = ("type", "count")).reset_index().sort_values("type_count", ascending = False)

# %%
brand_data
# Out:
#                      brand  type_count
# 2296              bb Combo          53
# 741                 Fresho          41
# 171                BB Home          37
# 507                  Dabur          34
# 2298              bb Royal          32
# ...                    ...         ...
# 1361            Mugi Fresh           1
# 1360                   Mud           1
# 1359  Mrs Bector'S Cremica           1
# 1358        Mr.Copper King           1
# 1157                Lexton           1
#
# [2314 rows x 2 columns]

# %% [markdown]
# **Visualize the top 10 brands**

# %%
brand_data_10 = brand_data.head(10)

# %%
fig = px.bar(brand_data_10, x = "brand", y = "type_count", color = "brand", title = "Analysis on the brand and kinds of category type they are dealing with")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="14682f52-95e0-4202-bc05-02fa69d7930b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14682f52-95e0-4202-bc05-02fa69d7930b")) {                    Plotly.newPlot(                        "14682f52-95e0-4202-bc05-02fa69d7930b",                        [{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bb Combo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"bb Combo","offsetgroup":"bb Combo","orientation":"v","showlegend":true,"textposition":"auto","x":["bb Combo"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fresho","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Fresho","offsetgroup":"Fresho","orientation":"v","showlegend":true,"textposition":"auto","x":["Fresho"],"xaxis":"x","y":[41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BB Home","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BB Home","offsetgroup":"BB Home","orientation":"v","showlegend":true,"textposition":"auto","x":["BB Home"],"xaxis":"x","y":[37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dabur","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Dabur","offsetgroup":"Dabur","orientation":"v","showlegend":true,"textposition":"auto","x":["Dabur"],"xaxis":"x","y":[34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bb Royal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"bb Royal","offsetgroup":"bb Royal","orientation":"v","showlegend":true,"textposition":"auto","x":["bb Royal"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DP","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"DP","offsetgroup":"DP","orientation":"v","showlegend":true,"textposition":"auto","x":["DP"],"xaxis":"x","y":[31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nutty Yogi","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Nutty Yogi","offsetgroup":"Nutty Yogi","orientation":"v","showlegend":true,"textposition":"auto","x":["Nutty Yogi"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NUTRIWISH","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"NUTRIWISH","offsetgroup":"NUTRIWISH","orientation":"v","showlegend":true,"textposition":"auto","x":["NUTRIWISH"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Patanjali","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Patanjali","offsetgroup":"Patanjali","orientation":"v","showlegend":true,"textposition":"auto","x":["Patanjali"],"xaxis":"x","y":[21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"brand=%{x}\u003cbr\u003etype_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Urban Platter","marker":{"color":"#FECB52","p ...

# %% [markdown]
# **Insights**
#   * **BB's own subsidiaries are dealing with a large category type of products**
#   * **Can we say that BB own subsidaries can be a potential supplier**
#   * **If we make BB, as our potential supplier. First thing it will less on cost, QA would be done already by BB**

# %% [markdown]
# <hr>
#
# **Objective 5 - Analyse the Categories and sub categories of the given data, and try to come up a useful insight that can give a idea about the demands related to a specific category and their associated sub-category**

# %%
subcatgory_data = df[["category", "sub_category"]]

subcatgory_data = subcatgory_data.drop_duplicates()

# %%
subcatgory_data
# Out:
#                        category           sub_category
# 0              Beauty & Hygiene              Hair Care
# 1        Kitchen, Garden & Pets  Storage & Accessories
# 2          Cleaning & Household            Pooja Needs
# 3          Cleaning & Household   Bins & Bathroom Ware
# 4              Beauty & Hygiene       Bath & Hand Wash
# ...                         ...                    ...
# 8815       Gourmet & World Food   Rice & Rice Products
# 12995    Snacks & Branded Foods         Cuts & Sprouts
# 13542      Gourmet & World Food          Mutton & Lamb
# 18845                 Baby Care   Atta, Flours & Sooji
# 19731  Foodgrains, Oil & Masala    Baby Food & Formula
#
# [99 rows x 2 columns]

# %%
subcatgory_data = subcatgory_data.groupby("category").agg(subcatgory_count = ("sub_category", "count")).reset_index().sort_values("subcatgory_count", ascending = False)

# %%
subcatgory_data.head(10)
# Out:
#                     category  subcatgory_count
# 8       Gourmet & World Food                14
# 10    Snacks & Branded Foods                12
# 2           Beauty & Hygiene                10
# 4       Cleaning & Household                10
# 9     Kitchen, Garden & Pets                10
# 6   Foodgrains, Oil & Masala                 9
# 1      Bakery, Cakes & Dairy                 8
# 0                  Baby Care                 7
# 7        Fruits & Vegetables                 7
# 3                  Beverages                 6

# %% [markdown]
# **Visualize**

# %%
fig = px.pie(subcatgory_data, values = subcatgory_data["subcatgory_count"], names = subcatgory_data["category"], color = "category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f82dec40-420a-4f30-b4aa-4e2d27bd4c9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f82dec40-420a-4f30-b4aa-4e2d27bd4c9b")) {                    Plotly.newPlot(                        "f82dec40-420a-4f30-b4aa-4e2d27bd4c9b",                        [{"customdata":[["Gourmet & World Food"],["Snacks & Branded Foods"],["Beauty & Hygiene"],["Cleaning & Household"],["Kitchen, Garden & Pets"],["Foodgrains, Oil & Masala"],["Bakery, Cakes & Dairy"],["Baby Care"],["Fruits & Vegetables"],["Beverages"],["Eggs, Meat & Fish"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"category=%{customdata[0]}\u003cbr\u003esubcatgory_count=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Gourmet & World Food","Snacks & Branded Foods","Beauty & Hygiene","Cleaning & Household","Kitchen, Garden & Pets","Foodgrains, Oil & Masala","Bakery, Cakes & Dairy","Baby Care","Fruits & Vegetables","Beverages","Eggs, Meat & Fish"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa"]},"name":"","showlegend":true,"values":[14,12,10,10,10,9,8,7,7,6,6],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillp ...

# %% [markdown]
# **Insights**
#   * **Though there is less no. of category in the Beauty & Hygiene but still in demand**
#   * **We can expand the category in the most product area that is Beauty & Hygiene, this will attract more consumer, eventually enhancing profits**

# %% [markdown]
# <hr>
#
# **Objective 6 - Analysis on the sales**

# %%
print(Back.GREEN + Style.BRIGHT + Fore.YELLOW + "Analysis on Sales" + Style.RESET_ALL)

print('Minimum Sale Price : '+ Fore.RED+ Style.BRIGHT+ str(df['sale_price'].min()) + Style.RESET_ALL)

print('Maximum Sale Price : '+ Fore.RED+ Style.BRIGHT+ str(df['sale_price'].max()) + Style.RESET_ALL)

print('Mean Sale Price    : '+ Fore.RED+ Style.BRIGHT+ str(round(df['sale_price'].mean())) + Style.RESET_ALL)

print('Median Sale Price  : '+ Fore.RED+ Style.BRIGHT+ str(round(df['sale_price'].median())) + Style.RESET_ALL)
# Out:
# Analysis on Sales
# Minimum Sale Price : 2
# Maximum Sale Price : 12500
# Mean Sale Price    : 323
# Median Sale Price  : 190

# %% [markdown]
# **Insights**
#   * **There is a huge difference between the price range, as we can see that the average price is near to 320 whereas the median or middle segment falls to 190, that means it's a straight case a skewness**
#   * **This mean that most of the products that we are having in the inventory are actually having price less than 500 (Assumption)**

# %%
fig = px.histogram(df, x = "sale_price")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="de5aa066-6783-4be5-a0c1-7b618bed19fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de5aa066-6783-4be5-a0c1-7b618bed19fc")) {                    Plotly.newPlot(                        "de5aa066-6783-4be5-a0c1-7b618bed19fc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sale_price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[220,180,119,149,162,169,58,250,1098,20,261,600,110,350,200,49,324,180,120,85,525,45,120,75,195,659,245,54,90,169,19,102,212,225,499,98,47,136,113,160,428,360,275,109,179,250,460,799,245,100,49,850,80,56,202,299,60,200,199,399,149,349,209,35,169,269,339,374,72,840,43,120,210,70,75,500,135,108,49,49,65,269,96,225,95,479,696,32,254,55,120,864,80,10,129,179,1200,33,259,1266,515,495,230,225,30,289,243,138,249,349,60,209,28,44,183,35,150,69,999,100,1099,53,23,269,183,179,30,455,1299,299,24,39,14,90,230,159,86,250,75,369,125,280,66,90,32,20,225,225,250,639,289,120,459,50,350,247,429,25,185,112,77,189,199,40,450,179,232,79,80,509,110,142,90,699,799,328,40,430,195,159,81,56,19,509,148,119,99,20,165,2369,150,699,333,155,75,558,10,33,68,378,40,4900,278,52,698,20,78,149,65,35,295,147,109,449,10,30,25,28,87,699,105,249,19,44,90,34,275,2059,249,225,330,140,32,99,319,49,166,199,135,972,240,95,350,289,60,80,112,218,649,110,300,432,609,1049,39,64,595,89,94,35,172,385,80,400,94,30,30,230,169,3500,109,125,270,409,285,1330,60,140,34,320,351,128,99,160,499,131,61,90,325,350,84,900,104,191,226,209,75,1200,273,475,94,399,38,630,236,259,549,297,249,231,300,475,28,360,150,150,29,285,86,63,38,425,219,295,789,1229,140,290,87,166,352,275,650,50,180,60,185,112,318,180,475,178,549,1901,171,65,3330,579,900,332,330,99,140,40,45,104,124,300,18,370,169,149,48,399,1987,410,210,389,320,499,608,20,180,1280,485,20,120,84,220,530,204,113,330,55,40,155,150,239,80,191,119,525,161,489,30,432,44,950,219,111,500,210,2060,349,36,47,307,22,209,395,109,82,115,739,292,319,879,13,223,296,23,129,190,161,249,121,69,100,340,27,275,25,149,79,27,220,99,49,130,209,419,409,239,420,349,38,209,37,80,216,70,638,79,1699,575,17,48,190,425,80,942,190,1436,195,145,53,256,52,279,279,395,157,149,85,50,80,145,468,259,27,175,589,346,219,196,150,32,180,349,195,117,173,299,24,270,200,300,150,292,656,1077,315,25,125,72,466,238,649,45,401,57,850,13,175,21,41,426,108,110,59,340,126,90,900,110,145,66,79,49,149,39,107,127,299,320,300,160,396,268,139,99,106,169,40,336,80,575,99,89,108,870,245,119,2415,675,98,120,229,139,68,60,40,75,99,195,166,572,359,450,475,176,220,325,625,525,1150,224,220,109,99,750,309,685,32,325,465,44,240,343,77,475,469,79,749,350,77,190,400,500,115,149,700,60,600,180,110,69,303,120,300,205,869,299,68,70,399,97,200,239,240,518,240,244,37,85,77,209,48,172,99,308,550,64,49,175,35,210,90,59,95,35,231,295,168,129,159,140,449,99,290,219,175,604,260,80,143,275,912,426,209,506,150,45,128,1500,550,66,147,90,349,99,230,15,185,450,3612,119,225,57,420,112,499,349,249,299,199,299,159,539,223,325,450,798,58,342,18,21,40,138,160,150,161,129,87,99,55,135,50,469,13,895,599,120,619,440,95,100,30,295,499,152,210,299,142,436,455,57,310,130,202,135,519,110,206,440,298,699,75,249,510,388,60,38,350,50,360,489,96,211,449,390,600,185,1319,450,1450,265,395,497,235,400,80,450,269,375,1180,295,26,75,450,120,409,70,50,160,1600,139,232,89,85,299,189,429,249,225,598,279,57,322,264,360,445,499,2000,145,114,149,158,482,120,595,198,600,120,115,295,90,1099,699,72,339,499,149,142,90,1195,36,307,100,249,405,697,100,349,209,109,105,38,140,199,219,194,195,150,164,58,929,28,44,226,153,550,180, ...

# %% [markdown]
# <hr>
#
# **Objective 7 - With the above analysis, can we get an idea of the range which is having most of the products**

# %%
# defining the ranges for the products

range_val = [
    ['1-10',1, 10],
 ['11-25', 11, 25],
  ['26-50', 26, 50],
   ['51-100',51, 100],
    ['101-150', 101, 150],
     ['151-200', 151, 200],
      ['201-300',201, 300],
       ['301-400', 301, 400],
        ['401-500', 401, 500],
         ['501-1000',501, 1000],
          ['1001-1500', 1001, 1500],
           ['1501-2000', 1501, 2000],
              ['2001-3000',2001, 3000],
               ['3001-5000', 3001, 5000],
                ['5001-10000', 5001, 10000],
                 ['10001-15000',10001, 15000]]

# %%
# Frame a dataframe
range_data = pd.DataFrame(range_val, columns = ["range_name", "min_value", "max_value"])

# Creating product
range_data["product_count"] = ""

# %%
range_data
# Out:
#      range_name  min_value  max_value product_count
# 0          1-10          1         10
# 1         11-25         11         25
# 2         26-50         26         50
# 3        51-100         51        100
# 4       101-150        101        150
# 5       151-200        151        200
# 6       201-300        201        300
# 7       301-400        301        400
# 8       401-500        401        500
# 9      501-1000        501       1000
# 10    1001-1500       1001       1500
# 11    1501-2000       1501       2000
# 12    2001-3000       2001       3000
# 13    3001-5000       3001       5000
# 14   5001-10000       5001      10000
# 15  10001-15000      10001      15000

# %%
# we are trying to find the number of products available in the given range
for index, rows in range_data.iterrows():
  range_data.at[index, "product_count"] = len(df['product'][(df['sale_price']>= rows['min_value']) & (df['sale_price']<= rows['max_value'])])

# %% [markdown]
# **Results**

# %%
# Dividing on the basis of pricing
range_data
# Out:
#      range_name  min_value  max_value product_count
# 0          1-10          1         10           178
# 1         11-25         11         25           689
# 2         26-50         26         50          2232
# 3        51-100         51        100          4654
# 4       101-150        101        150          3661
# 5       151-200        151        200          3196
# 6       201-300        201        300          4568
# 7       301-400        301        400          2555
# 8       401-500        401        500          1693
# 9      501-1000        501       1000          2773
# 10    1001-1500       1001       1500           666
# 11    1501-2000       1501       2000           300
# 12    2001-3000       2001       3000           222
# 13    3001-5000       3001       5000           122
# 14   5001-10000       5001      10000            44
# 15  10001-15000      10001      15000             2

# %% [markdown]
# **Visualize**

# %%
fig = px.bar(range_data, x = "range_name", y = "product_count", color = "range_name")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2c90de68-9385-4671-a3b5-216a25f15645" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c90de68-9385-4671-a3b5-216a25f15645")) {                    Plotly.newPlot(                        "2c90de68-9385-4671-a3b5-216a25f15645",                        [{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1-10","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1-10","offsetgroup":"1-10","orientation":"v","showlegend":true,"textposition":"auto","x":["1-10"],"xaxis":"x","y":[178],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"11-25","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"11-25","offsetgroup":"11-25","orientation":"v","showlegend":true,"textposition":"auto","x":["11-25"],"xaxis":"x","y":[689],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"26-50","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"26-50","offsetgroup":"26-50","orientation":"v","showlegend":true,"textposition":"auto","x":["26-50"],"xaxis":"x","y":[2232],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"51-100","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"51-100","offsetgroup":"51-100","orientation":"v","showlegend":true,"textposition":"auto","x":["51-100"],"xaxis":"x","y":[4654],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"101-150","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"101-150","offsetgroup":"101-150","orientation":"v","showlegend":true,"textposition":"auto","x":["101-150"],"xaxis":"x","y":[3661],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"151-200","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"151-200","offsetgroup":"151-200","orientation":"v","showlegend":true,"textposition":"auto","x":["151-200"],"xaxis":"x","y":[3196],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"201-300","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"201-300","offsetgroup":"201-300","orientation":"v","showlegend":true,"textposition":"auto","x":["201-300"],"xaxis":"x","y":[4568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"301-400","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"301-400","offsetgroup":"301-400","orientation":"v","showlegend":true,"textposition":"auto","x":["301-400"],"xaxis":"x","y":[2555],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"401-500","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"401-500","offsetgroup":"401-500","orientation":"v","showlegend":true,"textposition":"auto","x":["401-500"],"xaxis":"x","y":[1693],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"range_name=%{x}\u003cbr\u003eproduct_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e", ...

# %% [markdown]
# **Insights**
#   * **range from 26 to 1000 having more products focusing on mid range of price**
#   * **The range from 26-1000 is having more number of product, so our major focus can on on this range**

# %% [markdown]
# <hr>
#
# **Objective 8 - Analysis on the basis of percentages of discounts**

# %%
df[["product", "category", "discounts"]][df["discounts"]==df["discounts"].max()]
# Out:
#             product             category  discounts
# 26976  Curry Leaves  Fruits & Vegetables  86.666667

# %% [markdown]
# <hr>
#
# **Get the top 20 discounted products**

# %%
df[["product", "category", "discounts"]].sort_values("discounts", ascending = False).head(20).style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_af048_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_af048_row1_col2 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_af048_row2_col2 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_af048_row3_col2 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_af048_row4_col2 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_af048_row5_col2 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_af048_row6_col2, #T_af048_row7_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_af048_row8_col2 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_af048_row9_col2, #T_af048_row10_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_af048_row11_col2, #T_af048_row12_col2 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_af048_row13_col2 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_af048_row14_col2 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_af048_row15_col2 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_af048_row16_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_af048_row17_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_af048_row18_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_af048_row19_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_af048" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af048_level0_col0" class="col_heading level0 col0" >product</th>
#       <th id="T_af048_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_af048_level0_col2" class="col_heading level0 col2" >discounts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af048_level0_row0" class="row_heading level0 row0" >26976</th>
#       <td id="T_af048_row0_col0" class="data row0 col0" >Curry Leaves</td>
#       <td id="T_af048_row0_col1" class="data row0 col1" >Fruits & Vegetables</td>
#       <td id="T_af048_row0_col2" class="data row0 col2" >86.666667</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row1" class="row_heading level0 row1" >17713</th>
#       <td id="T_af048_row1_col0" class="data row1 col0" >Fruit & Vegetables Hand Juicer</td>
#       <td id="T_af048_row1_col1" class="data row1 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row1_col2" class="data row1 col2" >82.506266</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row2" class="row_heading level0 row2" >13318</th>
#       <td id="T_af048_row2_col0" class="data row2 col0" >Small Silicone Spatula With Plastic Handle - Assorted Colours</td>
#       <td id="T_af048_row2_col1" class="data row2 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row2_col2" class="data row2 col2" >81.203008</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row3" class="row_heading level0 row3" >13740</th>
#       <td id="T_af048_row3_col0" class="data row3 col0" >Decorative Party Light Big Star String LED Light 2 M - Multicolour</td>
#       <td id="T_af048_row3_col1" class="data row3 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row3_col2" class="data row3 col2" >80.982712</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row4" class="row_heading level0 row4" >10438</th>
#       <td id="T_af048_row4_col0" class="data row4 col0" >NHS 860 Temperature Control Professional Hair Straightener</td>
#       <td id="T_af048_row4_col1" class="data row4 col1" >Beauty & Hygiene</td>
#       <td id="T_af048_row4_col2" class="data row4 col2" >80.501044</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row5" class="row_heading level0 row5" >4562</th>
#       <td id="T_af048_row5_col0" class="data row5 col0" >Concealer Brush 930</td>
#       <td id="T_af048_row5_col1" class="data row5 col1" >Beauty & Hygiene</td>
#       <td id="T_af048_row5_col2" class="data row5 col2" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row6" class="row_heading level0 row6" >11473</th>
#       <td id="T_af048_row6_col0" class="data row6 col0" >Decorative Party Light Golden Bell String LED Light 7 M - Warm White</td>
#       <td id="T_af048_row6_col1" class="data row6 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row6_col2" class="data row6 col2" >79.239620</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row7" class="row_heading level0 row7" >13265</th>
#       <td id="T_af048_row7_col0" class="data row7 col0" >Decorative Party Light Golden Bell String LED Light 7 M - Multicolour</td>
#       <td id="T_af048_row7_col1" class="data row7 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row7_col2" class="data row7 col2" >79.239620</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row8" class="row_heading level0 row8" >10092</th>
#       <td id="T_af048_row8_col0" class="data row8 col0" >USB String Fairy Lights 3M 30 LED For Decoration - Multicolour</td>
#       <td id="T_af048_row8_col1" class="data row8 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row8_col2" class="data row8 col2" >78.696742</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row9" class="row_heading level0 row9" >24292</th>
#       <td id="T_af048_row9_col0" class="data row9 col0" >Steel Belly Shape Storage Dabba/ Container Set With PP Lid - Silver & Purple</td>
#       <td id="T_af048_row9_col1" class="data row9 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row9_col2" class="data row9 col2" >77.989950</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row10" class="row_heading level0 row10" >398</th>
#       <td id="T_af048_row10_col0" class="data row10 col0" >Steel Belly Shape Storage Dabba/ Container Set With PP Lid - Silver & Blue</td>
#       <td id="T_af048_row10_col1" class="data row10 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row10_col2" class="data row10 col2" >77.989950</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row11" class="row_heading level0 row11" >27007</th>
#       <td id="T_af048_row11_col0" class="data row11 col0" >Decorative Party Light Leaves String LED Light 7.5 M - Warm White</td>
#       <td id="T_af048_row11_col1" class="data row11 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row11_col2" class="data row11 col2" >77.477477</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row12" class="row_heading level0 row12" >9792</th>
#       <td id="T_af048_row12_col0" class="data row12 col0" >Decorative Party Light Pine String LED Light 7 M - Warm White</td>
#       <td id="T_af048_row12_col1" class="data row12 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row12_col2" class="data row12 col2" >77.477477</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row13" class="row_heading level0 row13" >19042</th>
#       <td id="T_af048_row13_col0" class="data row13 col0" >Big Silicone Spatula With Plastic Handle - Blue</td>
#       <td id="T_af048_row13_col1" class="data row13 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row13_col2" class="data row13 col2" >76.923077</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row14" class="row_heading level0 row14" >14975</th>
#       <td id="T_af048_row14_col0" class="data row14 col0" >NHS-900 Temperature Control Professional Hair Straightener</td>
#       <td id="T_af048_row14_col1" class="data row14 col1" >Beauty & Hygiene</td>
#       <td id="T_af048_row14_col2" class="data row14 col2" >76.513026</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row15" class="row_heading level0 row15" >16781</th>
#       <td id="T_af048_row15_col0" class="data row15 col0" >USB Universal Wall/Travel Charger Adapator - White</td>
#       <td id="T_af048_row15_col1" class="data row15 col1" >Kitchen, Garden & Pets</td>
#       <td id="T_af048_row15_col2" class="data row15 col2" >76.190476</td>
#     </tr>
#     <tr>
#       <th id="T_af048_level0_row16" class="row_heading level0 row16" >623</th>
#       <td id="T_af048_row16_col0" class="data row16 col0" >Cookies - Atta Desi Ghee</td>
#       <td id="T_af048_row16_col1" class="data row16 col1" >Bakery, Cakes & Dairy</td>
#       <td id="T_af048_row16_col2" class="data row16 col2" >75.167785</td>

# %% [markdown]
# <hr>
#
# **Find out the category based discounts**

# %%
# We are grabbing the data which is having discount as not zero, and then we are trying to find the average discount
# provided in that particular columns
category_discounts = df[df["discounts"]!=0].groupby("category").agg(Average_discounts = ("discounts", "mean")).reset_index()

# Sorting the discounts
category_discounts = category_discounts.sort_values("Average_discounts", ascending = False)

# Round off
category_discounts = category_discounts.round({"Average_discounts":2})

# %%
category_discounts
# Out:
#                     category  Average_discounts
# 9     Kitchen, Garden & Pets              28.62
# 7        Fruits & Vegetables              21.81
# 3                  Beverages              21.54
# 2           Beauty & Hygiene              20.88
# 6   Foodgrains, Oil & Masala              19.80
# 8       Gourmet & World Food              19.48
# 4       Cleaning & Household              19.47
# 10    Snacks & Branded Foods              17.63
# 0                  Baby Care              16.16
# 5          Eggs, Meat & Fish              16.04
# 1      Bakery, Cakes & Dairy              15.57

# %% [markdown]
# **Visualize**

# %%
fig = px.bar(category_discounts, x = "category", y = "Average_discounts", color = "category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a9a6a4c0-bd7d-47cc-847f-5cd2069a2fa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9a6a4c0-bd7d-47cc-847f-5cd2069a2fa2")) {                    Plotly.newPlot(                        "a9a6a4c0-bd7d-47cc-847f-5cd2069a2fa2",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kitchen, Garden & Pets","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Kitchen, Garden & Pets","offsetgroup":"Kitchen, Garden & Pets","orientation":"v","showlegend":true,"textposition":"auto","x":["Kitchen, Garden & Pets"],"xaxis":"x","y":[28.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fruits & Vegetables","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Fruits & Vegetables","offsetgroup":"Fruits & Vegetables","orientation":"v","showlegend":true,"textposition":"auto","x":["Fruits & Vegetables"],"xaxis":"x","y":[21.81],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Beverages","offsetgroup":"Beverages","orientation":"v","showlegend":true,"textposition":"auto","x":["Beverages"],"xaxis":"x","y":[21.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beauty & Hygiene","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Beauty & Hygiene","offsetgroup":"Beauty & Hygiene","orientation":"v","showlegend":true,"textposition":"auto","x":["Beauty & Hygiene"],"xaxis":"x","y":[20.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foodgrains, Oil & Masala","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Foodgrains, Oil & Masala","offsetgroup":"Foodgrains, Oil & Masala","orientation":"v","showlegend":true,"textposition":"auto","x":["Foodgrains, Oil & Masala"],"xaxis":"x","y":[19.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gourmet & World Food","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Gourmet & World Food","offsetgroup":"Gourmet & World Food","orientation":"v","showlegend":true,"textposition":"auto","x":["Gourmet & World Food"],"xaxis":"x","y":[19.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cleaning & Household","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Cleaning & Household","offsetgroup":"Cleaning & Household","orientation":"v","showlegend":true,"textposition":"auto","x":["Cleaning & Household"],"xaxis":"x","y":[19.47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eAverage_discounts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Snacks & Branded Foods","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Snacks & Branded Foods","offsetgroup":"Snacks & Branded Foods","orientation":"v","showlegend":true,"textposition":"auto","x":["Snacks & Branded Foods"],"xaxis":"x","y":[17.63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003c ...

# %% [markdown]
# **Insights**
#   * **the discount lies mostly between 15 to 25 and above 25% for niche products**
#   * **product which have less sale have max discounts**

# %% [markdown]
# <hr>
#
# **Objective 9 - Getting the idea about the most expensive item with their discounts and same with the cheapest items**

# %% [markdown]
# **For Expensive Products**

# %%
# Expensive products
expensive_products = df.nlargest(10, "sale_price")[["product",  "category", 'market_price', "sale_price", "discounts"]]

print(Back.YELLOW+ Style.BRIGHT+ 'Expensive Products: ' + Style.RESET_ALL)
print(expensive_products.to_string())
# Out:
# Expensive Products:
#                                                           product                category  market_price  sale_price  discounts
# 25301                                             Bravura Clipper  Kitchen, Garden & Pets         12500       12500   0.000000
# 21761               Pet Food - N&D Team Breeder Puppy Top Farmina  Kitchen, Garden & Pets         10090       10090   0.000000
# 12669                            Epilator SE9-9961 Legs-Body-Face        Beauty & Hygiene         10769        8184  24.004086
# 23082  Gas Stove-4 Burner Royale Plus Schott Glass, Black (40278)  Kitchen, Garden & Pets         12245        7999  34.675378
# 2781                                       Extra Virgin Olive Oil    Gourmet & World Food          7299        7299   0.000000
# 25797  4 Burner Gas Stove - Marvel Plus Glass Tables, GTM04 40355  Kitchen, Garden & Pets          9695        7270  25.012893
# 1056   Gas Stove-3 Burner Royale Plus Schott Glass, Black (40177)  Kitchen, Garden & Pets         10695        6999  34.558205
# 6034                                          Whey Protein Powder        Beauty & Hygiene          6700        6700   0.000000
# 1766                            Good Girl Eau De Parfum For Women        Beauty & Hygiene          7400        6660  10.000000
# 5464                                     Olive Oil - Extra Virgin    Gourmet & World Food          6500        6500   0.000000

# %% [markdown]
# **For cheapest products**

# %%
# Expensive products
expensive_products = df.nsmallest(10, "sale_price")[["product",  "category", 'market_price', "sale_price", "discounts"]]

print(Back.YELLOW+ Style.BRIGHT+ 'Cheapest Products: ' + Style.RESET_ALL)
print(expensive_products.to_string())
# Out:
# Cheapest Products:
#                                            product                category  market_price  sale_price  discounts
# 26976                                 Curry Leaves     Fruits & Vegetables            15           2  86.666667
# 21312                                        Serum        Beauty & Hygiene             3           3   0.000000
# 2761   Orbit Sugar-Free Chewing Gum - Lemon & Lime  Snacks & Branded Foods             5           5   0.000000
# 2978          Sugar Free Chewing Gum - Mixed Fruit  Snacks & Branded Foods             5           5   0.000000
# 3445                 Marie Light Biscuits - Active  Snacks & Branded Foods             5           5   0.000000
# 6014                       Good Day Butter Cookies  Snacks & Branded Foods             5           5   0.000000
# 9971             Tomato - Local, Organically Grown     Fruits & Vegetables             6           5  16.666667
# 11306               Happy Happy Choco-Chip Cookies  Snacks & Branded Foods             5           5   0.000000
# 11435                          Exam Standard Scale    Cleaning & Household             5           5   0.000000
# 14184            Tomato - Local, Organically Grown     Fruits & Vegetables             6           5  16.666667

# %% [markdown]
# <hr>
#
# **Insights**
#   * **snacks and foods will be consumed by everyone even without any discount, so even if there is no discount still this will be in demand**

# %% [markdown]
# <hr>
#
# **Objective 10 - Measure the standard variation to see how the discount varies in a particular category?**

# %%
# We are trying to group categories based on discounts, and then we are finding standard deviations
variation_data = df.groupby("category")["discounts"].std().mean()

# %%
variation_data
# Out:
# 12.561645837790525

# %% [markdown]
# <hr>
#
# **Objective 11 - Find the best brand based on rating, so that we can get best suppliers**

# %%
df["rating"].median()
# Out:
# 4.1

# %%
df["rating"].mean()
# Out:
# 3.943409583179249

# %%
fig = px.histogram(df, "rating")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7eb7dcb4-87f2-4bd2-b52d-91611ae8f8fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eb7dcb4-87f2-4bd2-b52d-91611ae8f8fd")) {                    Plotly.newPlot(                        "7eb7dcb4-87f2-4bd2-b52d-91611ae8f8fd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"rating=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4.1,2.3,3.4,3.7,4.4,3.3,3.6,4.0,3.5,4.3,4.0,2.2,5.0,3.8,4.2,4.0,5.0,4.9,4.3,3.9,4.2,4.1,3.9,3.9,5.0,3.3,3.5,4.0,4.3,1.5,2.9,4.2,3.4,3.7,3.9,4.1,3.9,4.1,3.7,4.4,4.3,4.2,4.3,2.6,5.0,3.9,3.9,4.0,3.7,3.0,4.1,4.2,4.0,4.0,4.5,3.943409583179249,3.9,4.4,3.7,3.943409583179249,3.5,4.0,4.3,4.0,1.0,3.943409583179249,3.9,4.0,3.943409583179249,3.943409583179249,4.0,4.3,3.5,3.6,3.943409583179249,3.0,4.3,4.6,3.943409583179249,3.9,3.9,3.943409583179249,3.9,3.943409583179249,3.943409583179249,3.943409583179249,3.943409583179249,4.6,4.2,3.943409583179249,3.943409583179249,4.6,5.0,4.1,1.5,4.0,3.943409583179249,4.4,3.7,4.0,3.943409583179249,3.943409583179249,4.8,3.7,4.4,3.6,3.943409583179249,3.6,3.3,4.0,4.6,5.0,4.2,3.943409583179249,4.0,3.943409583179249,4.3,3.943409583179249,3.943409583179249,4.5,3.8,4.2,3.943409583179249,3.0,4.1,3.9,4.2,3.943409583179249,3.943409583179249,3.943409583179249,4.3,3.943409583179249,3.943409583179249,4.2,4.4,3.7,3.943409583179249,3.943409583179249,3.9,4.8,3.6,4.2,4.1,3.9,4.2,3.943409583179249,3.943409583179249,4.5,3.7,3.3,3.943409583179249,4.3,3.5,3.943409583179249,4.3,3.943409583179249,4.5,3.943409583179249,3.943409583179249,3.1,4.2,3.7,4.1,4.3,3.943409583179249,4.3,4.0,3.943409583179249,3.7,3.6,4.0,3.0,4.4,3.9,3.943409583179249,4.5,4.3,5.0,3.943409583179249,4.0,3.943409583179249,3.9,4.2,3.943409583179249,3.943409583179249,4.2,4.4,3.4,3.943409583179249,3.943409583179249,3.943409583179249,2.0,4.2,4.4,3.943409583179249,3.943409583179249,3.943409583179249,4.3,3.6,3.7,4.1,3.943409583179249,3.943409583179249,4.4,3.943409583179249,4.0,4.3,3.9,3.7,1.8,3.943409583179249,4.2,4.2,5.0,3.943409583179249,4.5,4.3,4.8,4.3,4.1,3.943409583179249,4.1,3.943409583179249,4.1,4.3,3.943409583179249,5.0,3.0,3.943409583179249,5.0,3.943409583179249,3.6,3.943409583179249,4.3,3.5,4.0,4.4,3.5,5.0,3.943409583179249,3.943409583179249,2.8,5.0,3.943409583179249,4.2,3.943409583179249,4.0,4.3,3.943409583179249,4.1,3.943409583179249,5.0,3.943409583179249,4.1,3.943409583179249,4.0,3.943409583179249,3.2,4.2,4.7,3.943409583179249,4.5,4.4,2.5,4.1,5.0,4.2,4.4,3.943409583179249,3.943409583179249,4.0,3.943409583179249,4.4,3.943409583179249,4.5,5.0,3.943409583179249,4.1,3.943409583179249,3.9,3.0,3.943409583179249,3.943409583179249,3.5,3.943409583179249,4.3,4.3,4.5,5.0,4.5,3.943409583179249,3.943409583179249,3.3,3.943409583179249,4.3,3.7,3.9,3.943409583179249,1.0,1.0,4.1,3.9,4.3,5.0,3.0,4.2,2.5,3.943409583179249,4.4,4.3,3.943409583179249,2.6,4.3,3.943409583179249,3.943409583179249,3.943409583179249,3.6,3.943409583179249,4.2,4.1,4.3,3.943409583179249,2.8,3.943409583179249,3.943409583179249,3.8,3.943409583179249,3.943409583179249,3.943409583179249,4.5,3.943409583179249,3.943409583179249,3.5,3.943409583179249,4.0,4.1,3.943409583179249,2.5,3.943409583179249,4.2,4.5,4.1,2.4,3.943409583179249,4.2,4.3,3.5,3.943409583179249,5.0,3.4,3.943409583179249,4.2,3.943409583179249,4.0,4.3,4.3,4.2,4.0,4.1,5.0,5.0,3.943409583179249,4.1,4.1,3.943409583179249,3.943409583179249,2.0,3.8,4.3,3.943409583179249,5.0,4.2,4.3,3.943409583179249,4.0,4.0,3.5,4.1,3.943409583179249,3.943409583179249,3.943409583179249,3.943409583179249,3.943409583179249,4.0,4.4,4.3,3.94340958 ...

# %%
df["rating"] = df["rating"].fillna(df["rating"].mean())

# %%
best_rated_brand = df.groupby("brand")["rating"].mean().sort_values(ascending = False)

# %%
best_rated_brand.head()
# Out:
# brand
# DIVING DUCK    5.0
# Muscleblaze    5.0
# Depend         5.0
# LuxaDerme      5.0
# Pez            5.0
# Name: rating, dtype: float64

# %% [markdown]
# <hr>
#
# **Building a Regression Model for predicting market price with help of sales prices**

# %%
# library
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Divide the data
X = df[["sale_price", "market_price"]]

Y = df["discounts"]

# %%
X.shape
# Out:
# (27555, 1)

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 32)

# %%
# making a object to the LR
model = LinearRegression()

# Fit the data
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Predict
model.predict([[8990]])
# Out:
# array([10390.33493725])

# %%
r2_score()

# %% [markdown]
# **Model with split Data**

# %%
# making model 2
model2 = LinearRegression()


model2.fit(x_train, y_train)


pred = model2.predict(x_test)

# %%
error_data = pd.DataFrame(columns = ["Actual_Data", "Predicted_Data", "Errors"])

# %%
error_data["Actual_Data"] = y_test

error_data["Predicted_Data"] = pred

error_data["Errors"] = error_data["Actual_Data"] - error_data["Predicted_Data"]

# %%
error_data.head()
# Out:
#        Actual_Data  Predicted_Data      Errors
# 7440            52       69.384680  -17.384680
# 25164           45       61.307484  -16.307484
# 25902          275      295.546190  -20.546190
# 1676           455      280.545681  174.454319
# 9512           279      239.005812   39.994188

# %%
a = model2.predict([[279]])

# %%
a
# Out:
# array([331.31663246])

# %%
def discount(market, sales):
  return (((market - sales) / market) * 100)

# %%
discount(331, 279)
# Out:
# 15.709969788519636

# %%
from sklearn.metrics import *

print(r2_score(y_test, pred))
# Out:
# 0.9269535603496292

# %%
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 157.5896574573107
